# %%
from IPython.display import Image
display(Image(filename='SymPY.JPEG'))

# %%
# What is SymPy?

# %% [markdown]
# SymPy is a Python library that allows you to compute mathematical objects symbolically.

# %%
pip install sympy
# Out:
# Requirement already satisfied: sympy in c:\users\kiran\anaconda3\lib\site-packages (1.10.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\kiran\anaconda3\lib\site-packages (from sympy) (1.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Now let`s go over some of the amazing things that SymPy can do!
#
# Start with importing all methods provided by SymPy

# %%
from sympy import *

# %% [markdown]
# # Basic Operations

# %% [markdown]
# Normally, when computing a square root, we get a decimal:

# %%
18**(1/2)
# Out:
# 4.242640687119285

# %% [markdown]
# But with sympy, we can get a simplified version of the square root instead:

# %%
sqrt(18)
# Out:
# 3*sqrt(2)

# %% [markdown]
# It is because SymPy tries to represent mathematical objects exactly instead of approximately.

# %% [markdown]
# This, we will get a fraction instead of a decimal when dividing 2 numbers using SymPy:

# %%
25/15
# Out:
# 1.6666666666666667

# %%
frac=Rational(25,15)
frac
# Out:
# 5/3

# %% [markdown]
# # Symbols

# %% [markdown]
# The real power of SymPy is its ability to work with symbols.To create symbol, use the method symbols():

# %%
x,y= symbols('x y')
expr=3*x+y
expr
# Out:
# 3*x + y

# %% [markdown]
# Cool! We can create an expression in terms of x and y. What happens if we add a number to this expression?

# %%
expr+2
# Out:
# 3*x + y + 2

# %% [markdown]
# Aha! +2 is added to the expression and the expression remains unevaluated.

# %% [markdown]
# Why would working with symbols be useful? Because we can now use all kinds of math tricks we learn in school such a expanding,
# factoring and simplifying an equation to make our life easier.

# %% [markdown]
# # Equations

# %% [markdown]
# Expand,Factor and Simplify

# %% [markdown]
# We know that the expansion of the expression on the left is equal to the expression on the right.

# %% [markdown]
# x(3x+y)=3x2+xy

# %% [markdown]
# Can this be done with Sympy? Yes! SymPy allows us to expand an equation using expand:

# %%
expansion=expand(x*expr)
expansion
# Out:
# 3*x**2 + x*y

# %% [markdown]
# Another cool thing we can do with SymPy is to simplify an equation using simplify:

# %%
expr=(6*x**2+3*x)/(3*x)
expr
# Out:
# (6*x**2 + 3*x)/(3*x)

# %%
simplify(expr)
# Out:
# 2*x + 1

# %% [markdown]
# # Solve an Equation

# %% [markdown]
# One of the most common questions we see when dealing with mathematical symbols is to solve an equation. Luckily, this can also
# be done with SymPy:

# %% [markdown]
# To solve an equation, use solve:

# %%
eq=(2*x+1)*3*x
eq
# Out:
# x*(6*x + 3)

# %%
solve(eq,x)
# Out:
# [-1/2, 0]

# %% [markdown]
# # Substitution

# %% [markdown]
# If we substitute the equation below by 2, what do we get?
# x(6x+3)
#
# We can figure that out using eq.subs(x,2):

# %%
eq.subs(x,2)
# Out:
# 30

# %% [markdown]
# We can also substitute x with another variable to get an expressin like below:

# %%
eq.subs(x**2,2)
# Out:
# x*(6*x + 3)

# %% [markdown]
# # Trigonometric

# %% [markdown]
# Remember all the fun trigonometric identities we learn in high school:

# %% [markdown]
# To simplify expressions using trigonometric identities, use trigsimp()

# %%
trigsimp(1/sec(x))
# Out:
# cos(x)

# %%
trigsimp(sin(x)/cos(x))
# Out:
# tan(x)

# %%
trigsimp(sin(x)**2+cos(x)**2)
# Out:
# 1

# %%
trigsimp(1+cot(x)**2)
# Out:
# sin(x)**(-2)

# %% [markdown]
# # Derivatives, Integrals and Limit

# %% [markdown]
# With SymPy, you can also do calculus! What is the derivative of the expression below?

# %%
expr=sin(x)**2+2*x
expr
# Out:
# 2*x + sin(x)**2

# %% [markdown]
# If you cannot figure it out, don`t worry. We can use SymPy to figure it out.

# %%
res=diff(expr)
res
# Out:
# 2*sin(x)*cos(x) + 2

# %% [markdown]
# We can also take the limit as x approaces infinity:
#     lim x-> inf * 1/x2

# %%
limit(
1/(x**2),
x,oo,
)
# Out:
# 0

# %%
limit(
1/(x**2),
x,
2,
)
# Out:
# 1/4

# %% [markdown]
# Special Functions

# %% [markdown]
# SymPy also provides special functions to:

# %% [markdown]
# Find the factorial of a number

# %%
factorial(x)
# Out:
# factorial(x)

# %%
factorial(3)
# Out:
# 6

# %% [markdown]
# Rewrite the expression in terms of another

# %%
tan(x).rewrite(cos)
# Out:
# cos(x - pi/2)/cos(x)

# %% [markdown]
# # Print Latex

# %% [markdown]
# If you like the output and want to get the LaTex form of an expression,use latex:

# %%
print(latex(integrate(res)))
# Out:
# 2 x + \sin^{2}{\left(x \right)}

# %% [markdown]
# You could paste this LaTex form to yur notebook`s markdown and get a nice mathematical expression like below!
#
# $2 x + \sin^{2}{\left(x \right)}$

# %% [markdown]
# # Conclusion

# %% [markdown]
# You have just learned how to compute mathematical objects symbolically in Python using SymPy. The next time you solve math,
# try using SymPy to make your life easier.
#
# There are so many other useful methods SymPy provides that I could not covere here. I encourage you to check out this documentation
# for more inspiration.
